# %% [markdown]
# LangSmith

# %%
pip install langchain_openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 550.1/550.1 kB 16.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.0
#     Uninstalling langchain-core-1.4.0:
#       Successfully uninstalled langchain-core-1.4.0
# ...

# %%
pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata

# LangSmith
os.environ["LANGSMITH_API_KEY"] = userdata.get("Demo")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "my-langchain-project"

# Gemini
os.environ["GOOGLE_API_KEY"] = userdata.get("apikey")

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

response = llm.invoke(
    "Explain how LangSmith tracing works in one sentence."
)

print(response.content)
# Out:
# LangSmith tracing works by capturing and visualizing the full execution path of your LLM application, including all calls and intermediate steps, to provide detailed insights for debugging and evaluation.

# %%
import os
from google.colab import userdata
from langsmith import Client
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI




os.environ["LANGSMITH_API_KEY"] = userdata.get("Demo")
os.environ["GEMINI_API_KEY"] = userdata.get("apikey")




client = Client()




model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
prompt = ChatPromptTemplate.from_template("Tell me a brief {style} joke about {topic}.")




chain = prompt | model




url = client.push_prompt("gemini-joke-generator", object=chain)


print(f"Successfully pushed prompt! Access it here: {url}")
# Out:
# WARNING:google_genai._api_client:Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Successfully pushed prompt! Access it here: https://smith.langchain.com/prompts/gemini-joke-generator/edf0e7ae?organizationId=2738eac0-7db2-4b4d-b9dd-9c513738af38
