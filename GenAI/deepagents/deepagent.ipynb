# %%
pip install -qU deepagents langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.5/221.5 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 838.7/838.7 kB 7.8 MB/s eta 0:00:00

# %%
# !pip install -q langchain
# !pip install -q langchain-openai
# !pip install -q deepagents
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 1.3 MB/s eta 0:00:00

# %%
from langchain.chat_models import init_chat_model
from deepagents import create_deep_agent
from google.colab import userdata
import os

os.environ["OPENROUTER_API_KEY"] = userdata.get("key")

model = init_chat_model(
    model="openai/gpt-4o-mini",
    model_provider="openai",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ["OPENROUTER_API_KEY"]
)

agent = create_deep_agent(
    model=model,
    tools=[],  # No tools for now
    system_prompt="You are a research assistant."
)

response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "What is the current status of Mars exploration?"
            }
        ]
    }
)

print(response["messages"][-1].content)
# Out:
# Mars exploration currently involves several active missions and key developments:
#
# ### Recent Missions
# 1. **Perseverance Rover**:
#    - Launched in July 2020 and landed in February 2021.
#    - Aims to search for signs of ancient life and collect samples for future return.
#    - Recent findings include evidence of past water activity and organic molecules.
#
# 2. **Curiosity Rover**:
#    - Active since 2012, exploring Gale Crater.
#    - Focus on studying Mars' atmosphere and geology, revealing insights into its ancient environments.
#
# ### Ongoing Projects
# - **Mars Sample Return**: An initiative to bring back samples collected by Perseverance, in partnership with ESA, aiming for a launch in the late 2020s.
# - **ExoMars Mission**: Delayed due to technical issues; this ESA mission includes the Rosalind Franklin rover, which will search for life.
#
# ### International Efforts
# - **UAE's Hope Probe**: Offers data on Mars' atmosphere and climate since its orbiting in February 2021.
# - **China's Tianwen-1 Mission**: Includes an orbiter, lander, and Zhurong rover, launched in July 2020 and landed in May 2021, contributing to studies of Mars’ geography and minerals.
#
# ### Summary of Findings
# - Missions have provided evidence of ancient water and possible habitability.
# - The focus on sample collection is expected to yield new insights into Mars' geological history and potential for life.
#
# These efforts reflect both international collaboration and advancements in technology as we continue to explore Mars.
